# %%
### Reflecting DB
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from sqlalchemy import Column, Integer, String, Float
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import func
import pandas as pd

# %%
# Create the engine to connect to a sqlite file.
engine = create_engine("sqlite:///CCES_Ver61.sqlite")

# Declare a base using automap_base()
Base = automap_base()


Base.prepare(engine, reflect=True)

# Print all of the classses mapped to the Base (this provides a list of the table names in the sqlite.db)
Base.classes.keys()
# Out:
# ['Cces_16']

# %%
# Assign the CCES_16 class to a variable called 'CCES'
CCES = Base.classes.Cces_16

# %%
# Create a variable to manage session.queries later on...
session = Session(engine)
# session = Session(bind = engine)

# %% [markdown]
# # pd.query testing

# %%
stmt = session.query(CCES).statement
print(stmt)
# Out:
# SELECT "Cces_16".index, "Cces_16"."V101", "Cces_16".lookupzip, "Cces_16"."StateName", "Cces_16"."StateAbb", "Cces_16"."Latitude", "Cces_16"."Longitude", "Cces_16".countyfips, "Cces_16".birthyr, "Cces_16".gender, "Cces_16".educ, "Cces_16"."GunBackgroundChecks_16", "Cces_16"."ProhibitPublication_16", "Cces_16"."BanAssultWeapons_16", "Cces_16"."MakeCCPEasier_16", "Cces_16"."AlwaysAllowChoice_16", "Cces_16"."RapeIncestorHealth_16", "Cces_16"."ProhibitMoreThan20Weeks_16", "Cces_16"."Employersdeclinebenefits_16", "Cces_16"."ProhibitFedFunds_16", "Cces_16"."GayMarriage"
# FROM "Cces_16"

# %%
df = pd.read_sql_query(stmt, session.bind)
df.head(2)
# Out:
#    index       V101  lookupzip      StateName StateAbb   Latitude  Longitude  \
# 0      0  222168628       3442  New Hampshire       NH  44.001231 -71.579923
# 1      1  301400441       3303  New Hampshire       NH  44.001231 -71.579923
#
#    countyfips  birthyr  gender     ...     GunBackgroundChecks_16  \
# 0     33011.0     1969  female     ...                    Support
# 1     33013.0     1948  female     ...                    Support
#
#   ProhibitPublication_16 BanAssultWeapons_16 MakeCCPEasier_16  \
# 0                 Oppose              Oppose           Oppose
# 1                 Oppose             Support           Oppose
#
#   AlwaysAllowChoice_16 RapeIncestorHealth_16 ProhibitMoreThan20Weeks_16  \
# 0              Support                Oppose                    Support
# 1              Support                Oppose                     Oppose
#
#   Employersdeclinebenefits_16 ProhibitFedFunds_16 GayMarriage
# 0                      Oppose              Oppose     Support
# 1                      Oppose              Oppose     Support
#
# [2 rows x 21 columns]

# %%
print(list(df.columns)[11:])
# Out:
# ['GunBackgroundChecks_16', 'ProhibitPublication_16', 'BanAssultWeapons_16', 'MakeCCPEasier_16', 'AlwaysAllowChoice_16', 'RapeIncestorHealth_16', 'ProhibitMoreThan20Weeks_16', 'Employersdeclinebenefits_16', 'ProhibitFedFunds_16', 'GayMarriage']

# %%
type(stmt)
# Out:
# sqlalchemy.sql.annotation.AnnotatedSelect

# %% [markdown]
# # List of dropdown variables

# %%
#############################################
# Dropdown Variables mapped to Sql...
#############################################

# Gun Questions
GunBackgroundChecks_16 = CCES.GunBackgroundChecks_16
ProhibitPublication_16 = CCES.ProhibitPublication_16
BanAssultWeapons_16 = CCES.BanAssultWeapons_16
MakeCCPEasier_16 = CCES.MakeCCPEasier_16

# Abortion Questions
AlwaysAllowChoice_16 = CCES.AlwaysAllowChoice_16
RapeIncestorHealth_16 = CCES.RapeIncestorHealth_16
ProhibitMoreThan20Weeks_16 = CCES.ProhibitMoreThan20Weeks_16
Employersdeclinebenefits_16 = CCES.Employersdeclinebenefits_16
ProhibitFedFunds_16 = CCES.ProhibitFedFunds_16

# Gay Marriage Question
GayMarriage = CCES.GayMarriage
#############################################

# %% [markdown]
# # Flask Route - metadata totals testing

# %%
#############################################
# Creating metadata totals function for metadata totals flask route
#############################################

# %%
#############################################
# Function to return Totals - Total Support and Total Oppose for each issue
#############################################
def sample_metadatatotals(sample):
    """Return the totals for a given sample"""
    TotalResults = []
    
    Approve = {}
    Oppose = {}
    
    ApproveTemp = session.query(sample).filter(sample == 'Support').count()
    Approve['Approve'] = ApproveTemp
    TotalResults.append(Approve)
    
    OpposeTemp = session.query(sample).filter(sample == 'Oppose').count()
    Oppose['Oppose'] = OpposeTemp
    TotalResults.append(Oppose)

    print(TotalResults)
#     return jsonify(TotalResults)

# %%
#############################################
# Metadatatotals Function Testing 1

sample_metadatatotals(GayMarriage)

# %%
#############################################
# Metadatatotals Function Testing 2

sample_metadatatotals(CCES.GunBackgroundChecks_16)

# %%
#############################################
# Metadatatotals Function - without function - direct query to verify results

ApproveGay = session.query(CCES.GayMarriage).filter(CCES.GayMarriage == 'Support').count()
OpposeGay = session.query(CCES).filter(CCES.GayMarriage == 'Oppose').count()
print(f'Sqlite query of votes supporting Gay Marrige: {ApproveGay}')
print(f'Sqlite query of votes opposint Gay Marriage: {OpposeGay}')

# %% [markdown]
# # Flask Route - Metadata States Groupby Results

# %%
#############################################
# Metadata States Groupby Function
#############################################

def Metadata_States(sample):
    
    # Query to create two lists of tuples (state, number)
    #S1 [4] i
    StatesFor = session.query(CCES.StateName, CCES.Latitude, CCES.Longitude, func.count(sample)).\
                filter(sample == 'Support').\
                group_by(CCES.StateName).all()
    #S2 [1] m
    StatesForM = session.query(CCES.StateName, CCES.gender, func.count(sample)).\
                filter(and_(sample == 'Support'),(CCES.gender == 'male')).group_by(CCES.StateName).all()
    #S3 [1] f
    StatesForF = session.query(CCES.StateName, CCES.gender, func.count(sample)).\
                filter(and_(sample == 'Support'),(CCES.gender == 'female')).group_by(CCES.StateName).all()
    #O1 [1] j
    StatesNot = session.query(CCES.StateName, func.count(sample)).\
                filter(sample == 'Oppose').\
                group_by(CCES.StateName).all()
    #O2 [1] n
    StatesNotM = session.query(CCES.StateName, CCES.gender, func.count(sample)).\
                filter(and_(sample == 'Oppose'),(CCES.gender == 'male')).group_by(CCES.StateName).all()
    #O3 [1] g
    StatesNotF = session.query(CCES.StateName, CCES.gender, func.count(sample)).\
                filter(and_(sample == 'Oppose'),(CCES.gender == 'female')).group_by(CCES.StateName).all()

    # List that will hold final dictionaries - to be jsonified
    States_Results = []
    
    for i, m, f, j, n, g in zip(StatesFor, StatesForM, StatesForF, StatesNot, StatesNotM, StatesNotF):
        
        #Determine if the state is more in support or oppose
        if i[1] > j[1]:
            tempoverall = 'Support'
        else:
            tempoverall = 'Oppose'
        

        # Build dictionary
        tempfile = {}
        tempfile['state'] = {
            'StateName' : i[0],
            'Lat' : i[1],
            'Long' : i[2]
        }
        tempfile['voteTotal'] = {
            'Support' : i[3],
            'Oppose' : j[1],
            'Overall' : tempoverall
        }
        tempfile['genderVote'] = {
            'MaleSupport' : m[2],
            'FemaleSupport' : f[2],
            'MaleOppose' : n[2],
            'FemaleOppose' : g[2],
        }
        States_Results.append(tempfile)

    return States_Results

# %%
Metadata_States(GayMarriage)
# Out:
# [{'state': {'StateName': 'Alabama',
#    'Lat': 32.601011199999995,
#    'Long': -86.6807365},
#   'voteTotal': {'Support': 395, 'Oppose': 369, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 141,
#    'FemaleSupport': 254,
#    'MaleOppose': 149,
#    'FemaleOppose': 220}},
#  {'state': {'StateName': 'Alaska', 'Lat': 61.3025006, 'Long': -158.7750198},
#   'voteTotal': {'Support': 67, 'Oppose': 42, 'Overall': 'Support'},
#   'genderVote': {'MaleSupport': 34,
#    'FemaleSupport': 33,
#    'MaleOppose': 20,
#    'FemaleOppose': 22}},
#  {'state': {'StateName': 'Arizona', 'Lat': 34.1682185, 'Long': -111.930907},
#   'voteTotal': {'Support': 948, 'Oppose': 517, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 425,
#    'FemaleSupport': 523,
#    'MaleOppose': 269,
#    'FemaleOppose': 248}},
#  {'state': {'StateName': 'Arkansas',
#    'Lat': 34.7519275,
#    'Long': -92.13137840000002},
#   'voteTotal': {'Support': 262, 'Oppose': 263, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 96,
#    'FemaleSupport': 166,
#    'MaleOppose': 104,
#    'FemaleOppose': 159}},
#  {'state': {'StateName': 'California',
#    'Lat': 37.2718745,
#    'Long': -119.2704153},
#   'voteTotal': {'Support': 4119, 'Oppose': 1741, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 2012,
#    'FemaleSupport': 2107,
#    'MaleOppose': 984,
#    'FemaleOppose': 757}},
#  {'state': {'StateName': 'Colorado',
#    'Lat': 38.9979339,
#    'Long': -105.55056699999999},
#   'voteTotal': {'Support': 673, 'Oppose': 311, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 303,
#    'FemaleSupport': 370,
#    'MaleOppose': 163,
#    'FemaleOppose': 148}},
#  {'state': {'StateName': 'Connecticut',
#    'Lat': 41.518783500000005,
#    'Long': -72.75750699999999},
#   'voteTotal': {'Support': 532, 'Oppose': 178, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 257,
#    'FemaleSupport': 275,
#    'MaleOppose': 93,
#    'FemaleOppose': 85}},
#  {'state': {'StateName': 'Delaware',
#    'Lat': 39.145251,
#    'Long': -75.41892059999999},
#   'voteTotal': {'Support': 180, 'Oppose': 81, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 79,
#    'FemaleSupport': 101,
#    'MaleOppose': 33,
#    'FemaleOppose': 48}},
#  {'state': {'StateName': 'District of Columbia',
#    'Lat': 38.899348700000004,
#    'Long': -77.0145666},
#   'voteTotal': {'Support': 155, 'Oppose': 31, 'Overall': 'Support'},
#   'genderVote': {'MaleSupport': 74,
#    'FemaleSupport': 81,
#    'MaleOppose': 17,
#    'FemaleOppose': 14}},
#  {'state': {'StateName': 'Florida', 'Lat': 27.9757279, 'Long': -83.8330166},
#   'voteTotal': {'Support': 3082, 'Oppose': 1773, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 1384,
#    'FemaleSupport': 1698,
#    'MaleOppose': 919,
#    'FemaleOppose': 854}},
#  {'state': {'StateName': 'Georgia',
#    'Lat': 32.6781248,
#    'Long': -83.22297569999999},
#   'voteTotal': {'Support': 1162, 'Oppose': 838, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 469,
#    'FemaleSupport': 693,
#    'MaleOppose': 363,
#    'FemaleOppose': 475}},
#  {'state': {'StateName': 'Hawaii', 'Lat': 20.46, 'Long': -157.505},
#   'voteTotal': {'Support': 130, 'Oppose': 62, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 70,
#    'FemaleSupport': 60,
#    'MaleOppose': 37,
#    'FemaleOppose': 25}},
#  {'state': {'StateName': 'Idaho', 'Lat': 45.4945756, 'Long': -114.1424303},
#   'voteTotal': {'Support': 178, 'Oppose': 139, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 82,
#    'FemaleSupport': 96,
#    'MaleOppose': 71,
#    'FemaleOppose': 68}},
#  {'state': {'StateName': 'Illinois', 'Lat': 39.739318, 'Long': -89.504139},
#   'voteTotal': {'Support': 1758, 'Oppose': 811, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 750,
#    'FemaleSupport': 1008,
#    'MaleOppose': 422,
#    'FemaleOppose': 389}},
#  {'state': {'StateName': 'Indiana', 'Lat': 39.7662195, 'Long': -86.441277},
#   'voteTotal': {'Support': 847, 'Oppose': 521, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 347,
#    'FemaleSupport': 500,
#    'MaleOppose': 237,
#    'FemaleOppose': 284}},
#  {'state': {'StateName': 'Iowa', 'Lat': 41.9383166, 'Long': -93.389798},
#   'voteTotal': {'Support': 460, 'Oppose': 209, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 185,
#    'FemaleSupport': 275,
#    'MaleOppose': 98,
#    'FemaleOppose': 111}},
#  {'state': {'StateName': 'Kansas',
#    'Lat': 38.4987789,
#    'Long': -98.32007790000002},
#   'voteTotal': {'Support': 347, 'Oppose': 183, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 168,
#    'FemaleSupport': 179,
#    'MaleOppose': 99,
#    'FemaleOppose': 84}},
#  {'state': {'StateName': 'Kentucky',
#    'Lat': 37.8222935,
#    'Long': -85.76823990000001},
#   'voteTotal': {'Support': 519, 'Oppose': 390, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 204,
#    'FemaleSupport': 315,
#    'MaleOppose': 163,
#    'FemaleOppose': 227}},
#  {'state': {'StateName': 'Louisiana',
#    'Lat': 30.9733766,
#    'Long': -91.42990970000001},
#   'voteTotal': {'Support': 354, 'Oppose': 322, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 148,
#    'FemaleSupport': 206,
#    'MaleOppose': 153,
#    'FemaleOppose': 169}},
#  {'state': {'StateName': 'Maine', 'Lat': 45.2185133, 'Long': -69.0148656},
#   'voteTotal': {'Support': 232, 'Oppose': 92, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 97,
#    'FemaleSupport': 135,
#    'MaleOppose': 46,
#    'FemaleOppose': 46}},
#  {'state': {'StateName': 'Maryland',
#    'Lat': 38.806352399999994,
#    'Long': -77.2684162},
#   'voteTotal': {'Support': 815, 'Oppose': 352, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 342,
#    'FemaleSupport': 473,
#    'MaleOppose': 188,
#    'FemaleOppose': 164}},
#  {'state': {'StateName': 'Massachusetts',
#    'Lat': 42.062939799999995,
#    'Long': -71.718067},
#   'voteTotal': {'Support': 1111, 'Oppose': 291, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 511,
#    'FemaleSupport': 600,
#    'MaleOppose': 176,
#    'FemaleOppose': 115}},
#  {'state': {'StateName': 'Michigan',
#    'Lat': 44.9435598,
#    'Long': -86.41580490000001},
#   'voteTotal': {'Support': 1332, 'Oppose': 740, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 533,
#    'FemaleSupport': 799,
#    'MaleOppose': 336,
#    'FemaleOppose': 404}},
#  {'state': {'StateName': 'Minnesota', 'Lat': 46.4418595, 'Long': -93.3655146},
#   'voteTotal': {'Support': 711, 'Oppose': 343, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 315,
#    'FemaleSupport': 396,
#    'MaleOppose': 183,
#    'FemaleOppose': 160}},
#  {'state': {'StateName': 'Mississippi',
#    'Lat': 32.5851062,
#    'Long': -89.8772196},
#   'voteTotal': {'Support': 195, 'Oppose': 204, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 79,
#    'FemaleSupport': 116,
#    'MaleOppose': 78,
#    'FemaleOppose': 126}},
#  {'state': {'StateName': 'Missouri', 'Lat': 38.3046615, 'Long': -92.437099},
#   'voteTotal': {'Support': 778, 'Oppose': 492, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 307,
#    'FemaleSupport': 471,
#    'MaleOppose': 252,
#    'FemaleOppose': 240}},
#  {'state': {'StateName': 'Montana',
#    'Lat': 46.6797995,
#    'Long': -110.04478300000001},
#   'voteTotal': {'Support': 105, 'Oppose': 82, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 45,
#    'FemaleSupport': 60,
#    'MaleOppose': 45,
#    'FemaleOppose': 37}},
#  {'state': {'StateName': 'Nebraska', 'Lat': 41.5008195, 'Long': -99.680902},
#   'voteTotal': {'Support': 225, 'Oppose': 137, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 96,
#    'FemaleSupport': 129,
#    'MaleOppose': 58,
#    'FemaleOppose': 79}},
#  {'state': {'StateName': 'Nevada', 'Lat': 38.502032, 'Long': -117.0230604},
#   'voteTotal': {'Support': 466, 'Oppose': 220, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 206,
#    'FemaleSupport': 260,
#    'MaleOppose': 120,
#    'FemaleOppose': 100}},
#  {'state': {'StateName': 'New Hampshire',
#    'Lat': 44.00123060000001,
#    'Long': -71.57992309999999},
#   'voteTotal': {'Support': 294, 'Oppose': 71, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 137,
#    'FemaleSupport': 157,
#    'MaleOppose': 39,
#    'FemaleOppose': 32}},
#  {'state': {'StateName': 'New Jersey', 'Lat': 40.1430058, 'Long': -74.7311156},
#   'voteTotal': {'Support': 1288, 'Oppose': 496, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 588,
#    'FemaleSupport': 700,
#    'MaleOppose': 269,
#    'FemaleOppose': 227}},
#  {'state': {'StateName': 'New Mexico',
#    'Lat': 34.1662325,
#    'Long': -106.02606850000001},
#   'voteTotal': {'Support': 254, 'Oppose': 120, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 104,
#    'FemaleSupport': 150,
#    'MaleOppose': 60,
#    'FemaleOppose': 60}},
#  {'state': {'StateName': 'New York', 'Lat': 40.7056258, 'Long': -73.97968},
#   'voteTotal': {'Support': 3053, 'Oppose': 1149, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 1447,
#    'FemaleSupport': 1606,
#    'MaleOppose': 663,
#    'FemaleOppose': 486}},
#  {'state': {'StateName': 'North Carolina',
#    'Lat': 35.2145629,
#    'Long': -79.8912675},
#   'voteTotal': {'Support': 1126, 'Oppose': 828, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 472,
#    'FemaleSupport': 654,
#    'MaleOppose': 348,
#    'FemaleOppose': 480}},
#  {'state': {'StateName': 'North Dakota',
#    'Lat': 47.467881899999995,
#    'Long': -100.3022655},
#   'voteTotal': {'Support': 76, 'Oppose': 47, 'Overall': 'Support'},
#   'genderVote': {'MaleSupport': 32,
#    'FemaleSupport': 44,
#    'MaleOppose': 25,
#    'FemaleOppose': 22}},
#  {'state': {'StateName': 'Ohio', 'Lat': 40.1903624, 'Long': -82.6692525},
#   'voteTotal': {'Support': 1676, 'Oppose': 964, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 666,
#    'FemaleSupport': 1010,
#    'MaleOppose': 461,
#    'FemaleOppose': 503}},
#  {'state': {'StateName': 'Oklahoma',
#    'Lat': 35.309765399999996,
#    'Long': -98.71655849999999},
#   'voteTotal': {'Support': 347, 'Oppose': 259, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 126,
#    'FemaleSupport': 221,
#    'MaleOppose': 107,
#    'FemaleOppose': 152}},
#  {'state': {'StateName': 'Oregon', 'Lat': 44.1419049, 'Long': -120.5380993},
#   'voteTotal': {'Support': 672, 'Oppose': 309, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 301,
#    'FemaleSupport': 371,
#    'MaleOppose': 174,
#    'FemaleOppose': 135}},
#  {'state': {'StateName': 'Pennsylvania',
#    'Lat': 40.99459279999999,
#    'Long': -77.6046984},
#   'voteTotal': {'Support': 2291, 'Oppose': 1148, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 880,
#    'FemaleSupport': 1411,
#    'MaleOppose': 551,
#    'FemaleOppose': 597}},
#  {'state': {'StateName': 'Rhode Island',
#    'Lat': 41.5827282,
#    'Long': -71.5064508},
#   'voteTotal': {'Support': 167, 'Oppose': 40, 'Overall': 'Support'},
#   'genderVote': {'MaleSupport': 74,
#    'FemaleSupport': 93,
#    'MaleOppose': 24,
#    'FemaleOppose': 16}},
#  {'state': {'StateName': 'South Carolina',
#    'Lat': 33.62505,
#    'Long': -80.9470381},
#   'voteTotal': {'Support': 431, 'Oppose': 405, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 165,
#    'FemaleSupport': 266,
#    'MaleOppose': 159,
#    'FemaleOppose': 246}},
#  {'state': {'StateName': 'South Dakota',
#    'Lat': 44.2126995,
#    'Long': -100.24716409999999},
#   'voteTotal': {'Support': 98, 'Oppose': 64, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 42,
#    'FemaleSupport': 56,
#    'MaleOppose': 34,
#    'FemaleOppose': 30}},
#  {'state': {'StateName': 'Tennessee',
#    'Lat': 35.830521000000005,
#    'Long': -85.97859890000001},
#   'voteTotal': {'Support': 609, 'Oppose': 576, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 231,
#    'FemaleSupport': 378,
#    'MaleOppose': 266,
#    'FemaleOppose': 310}},
#  {'state': {'StateName': 'Texas', 'Lat': 31.1693363, 'Long': -100.0768425},
#   'voteTotal': {'Support': 2600, 'Oppose': 1722, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 1103,
#    'FemaleSupport': 1497,
#    'MaleOppose': 882,
#    'FemaleOppose': 840}},
#  {'state': {'StateName': 'Utah', 'Lat': 39.4997605, 'Long': -111.547028},
#   'voteTotal': {'Support': 284, 'Oppose': 223, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 143,
#    'FemaleSupport': 141,
#    'MaleOppose': 123,
#    'FemaleOppose': 100}},
#  {'state': {'StateName': 'Vermont', 'Lat': 43.8717545, 'Long': -72.4477828},
#   'voteTotal': {'Support': 99, 'Oppose': 28, 'Overall': 'Support'},
#   'genderVote': {'MaleSupport': 50,
#    'FemaleSupport': 49,
#    'MaleOppose': 14,
#    'FemaleOppose': 14}},
#  {'state': {'StateName': 'Virginia', 'Lat': 38.0033855, 'Long': -79.4587861},
#   'voteTotal': {'Support': 1272, 'Oppose': 679, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 549,
#    'FemaleSupport': 723,
#    'MaleOppose': 343,
#    'FemaleOppose': 336}},
#  {'state': {'StateName': 'Washington',
#    'Lat': 38.899348700000004,
#    'Long': -77.0145665},
#   'voteTotal': {'Support': 1000, 'Oppose': 406, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 471,
#    'FemaleSupport': 529,
#    'MaleOppose': 229,
#    'FemaleOppose': 177}},
#  {'state': {'StateName': 'West Virginia',
#    'Lat': 38.920170500000005,
#    'Long': -80.1816905},
#   'voteTotal': {'Support': 235, 'Oppose': 184, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 88,
#    'FemaleSupport': 147,
#    'MaleOppose': 92,
#    'FemaleOppose': 92}},
#  {'state': {'StateName': 'Wisconsin',
#    'Lat': 44.7862968,
#    'Long': -89.82670490000001},
#   'voteTotal': {'Support': 881, 'Oppose': 440, 'Overall': 'Oppose'},
#   'genderVote': {'MaleSupport': 351,
#    'FemaleSupport': 530,
#    'MaleOppose': 208,
#    'FemaleOppose': 232}},
#  {'state': {'StateName': 'Wyoming', 'Lat': 43.000325, 'Long': -107.5545669},
#   'voteTotal': {'Support': 64, 'Oppose': 34, 'Overall': 'Support'},
#   'genderVote': {'MaleSupport': 30,
#    'FemaleSupport': 34,
#    'MaleOppose': 14,
#    'FemaleOppose': 20}}]

# %%
from sqlalchemy import and_, or_, not_

# %%
TempList = []



testdict = {}
testdict['State'] = {
    'StateName' : 'MN',
    'Lat' : 123,
    'long' : 345
}
testdict['votetotal'] = {
    'support' : 514654,
    'oppose' : 1354563,
    'Overall' : 'support'
}

testdict['Gender'] = {
    'Msupport' : 54654,
    'Fsupport' : 54654,
    'Moppose' : 14545,
    'Foppose' : 665654
}
testdict
# Out:
# {'State': {'StateName': 'MN', 'Lat': 123, 'long': 345},
#  'votetotal': {'support': 514654, 'oppose': 1354563, 'Overall': 'support'},
#  'Gender': {'Msupport': 54654,
#   'Fsupport': 54654,
#   'Moppose': 14545,
#   'Foppose': 665654}}

# %%
testdict['State']['Lat']
# Out:
# 123

# %%
tempList = []

# %%
#############################################
# Metadata States Function Testing 1

Metadata_States(GunBackgroundChecks_16)
# Out:
# [{'State': 'Alabama',
#   'Lat': 32.601011199999995,
#   'long': -86.6807365,
#   'Support': 676,
#   'Oppose': 88,
#   'Overall': 'Oppose'},
#  {'State': 'Alaska',
#   'Lat': 61.3025006,
#   'long': -158.7750198,
#   'Support': 85,
#   'Oppose': 24,
#   'Overall': 'Support'},
#  {'State': 'Arizona',
#   'Lat': 34.1682185,
#   'long': -111.930907,
#   'Support': 1265,
#   'Oppose': 200,
#   'Overall': 'Oppose'},
#  {'State': 'Arkansas',
#   'Lat': 34.7519275,
#   'long': -92.13137840000002,
#   'Support': 465,
#   'Oppose': 60,
#   'Overall': 'Oppose'},
#  {'State': 'California',
#   'Lat': 37.2718745,
#   'long': -119.2704153,
#   'Support': 5367,
#   'Oppose': 493,
#   'Overall': 'Oppose'},
#  {'State': 'Colorado',
#   'Lat': 38.9979339,
#   'long': -105.55056699999999,
#   'Support': 863,
#   'Oppose': 121,
#   'Overall': 'Oppose'},
#  {'State': 'Connecticut',
#   'Lat': 41.518783500000005,
#   'long': -72.75750699999999,
#   'Support': 660,
#   'Oppose': 50,
#   'Overall': 'Oppose'},
#  {'State': 'Delaware',
#   'Lat': 39.145251,
#   'long': -75.41892059999999,
#   'Support': 243,
#   'Oppose': 18,
#   'Overall': 'Support'},
#  {'State': 'District of Columbia',
#   'Lat': 38.899348700000004,
#   'long': -77.0145666,
#   'Support': 171,
#   'Oppose': 15,
#   'Overall': 'Support'},
#  {'State': 'Florida',
#   'Lat': 27.9757279,
#   'long': -83.8330166,
#   'Support': 4440,
#   'Oppose': 415,
#   'Overall': 'Oppose'},
#  {'State': 'Georgia',
#   'Lat': 32.6781248,
#   'long': -83.22297569999999,
#   'Support': 1804,
#   'Oppose': 196,
#   'Overall': 'Oppose'},
#  {'State': 'Hawaii',
#   'Lat': 20.46,
#   'long': -157.505,
#   'Support': 182,
#   'Oppose': 10,
#   'Overall': 'Support'},
#  {'State': 'Idaho',
#   'Lat': 45.4945756,
#   'long': -114.1424303,
#   'Support': 254,
#   'Oppose': 63,
#   'Overall': 'Oppose'},
#  {'State': 'Illinois',
#   'Lat': 39.739318,
#   'long': -89.504139,
#   'Support': 2379,
#   'Oppose': 190,
#   'Overall': 'Oppose'},
#  {'State': 'Indiana',
#   'Lat': 39.7662195,
#   'long': -86.441277,
#   'Support': 1259,
#   'Oppose': 109,
#   'Overall': 'Oppose'},
#  {'State': 'Iowa',
#   'Lat': 41.9383166,
#   'long': -93.389798,
#   'Support': 608,
#   'Oppose': 61,
#   'Overall': 'Oppose'},
#  {'State': 'Kansas',
#   'Lat': 38.4987789,
#   'long': -98.32007790000002,
#   'Support': 472,
#   'Oppose': 58,
#   'Overall': 'Oppose'},
#  {'State': 'Kentucky',
#   'Lat': 37.8222935,
#   'long': -85.76823990000001,
#   'Support': 809,
#   'Oppose': 100,
#   'Overall': 'Oppose'},
#  {'State': 'Louisiana',
#   'Lat': 30.9733766,
#   'long': -91.42990970000001,
#   'Support': 604,
#   'Oppose': 72,
#   'Overall': 'Oppose'},
#  {'State': 'Maine',
#   'Lat': 45.2185133,
#   'long': -69.0148656,
#   'Support': 232,
#   'Oppose': 92,
#   'Overall': 'Oppose'},
#  {'State': 'Maryland',
#   'Lat': 38.806352399999994,
#   'long': -77.2684162,
#   'Support': 1089,
#   'Oppose': 78,
#   'Overall': 'Oppose'},
#  {'State': 'Massachusetts',
#   'Lat': 42.062939799999995,
#   'long': -71.718067,
#   'Support': 1315,
#   'Oppose': 87,
#   'Overall': 'Oppose'},
#  {'State': 'Michigan',
#   'Lat': 44.9435598,
#   'long': -86.41580490000001,
#   'Support': 1902,
#   'Oppose': 170,
#   'Overall': 'Oppose'},
#  {'State': 'Minnesota',
#   'Lat': 46.4418595,
#   'long': -93.3655146,
#   'Support': 934,
#   'Oppose': 120,
#   'Overall': 'Oppose'},
#  {'State': 'Mississippi',
#   'Lat': 32.5851062,
#   'long': -89.8772196,
#   'Support': 358,
#   'Oppose': 41,
#   'Overall': 'Oppose'},
#  {'State': 'Missouri',
#   'Lat': 38.3046615,
#   'long': -92.437099,
#   'Support': 1124,
#   'Oppose': 146,
#   'Overall': 'Oppose'},
#  {'State': 'Montana',
#   'Lat': 46.6797995,
#   'long': -110.04478300000001,
#   'Support': 131,
#   'Oppose': 56,
#   'Overall': 'Oppose'},
#  {'State': 'Nebraska',
#   'Lat': 41.5008195,
#   'long': -99.680902,
#   'Support': 326,
#   'Oppose': 36,
#   'Overall': 'Support'},
#  {'State': 'Nevada',
#   'Lat': 38.502032,
#   'long': -117.0230604,
#   'Support': 559,
#   'Oppose': 127,
#   'Overall': 'Oppose'},
#  {'State': 'New Hampshire',
#   'Lat': 44.00123060000001,
#   'long': -71.57992309999999,
#   'Support': 333,
#   'Oppose': 32,
#   'Overall': 'Support'},
#  {'State': 'New Jersey',
#   'Lat': 40.1430058,
#   'long': -74.7311156,
#   'Support': 1685,
#   'Oppose': 99,
#   'Overall': 'Oppose'},
#  {'State': 'New Mexico',
#   'Lat': 34.1662325,
#   'long': -106.02606850000001,
#   'Support': 326,
#   'Oppose': 48,
#   'Overall': 'Oppose'},
#  {'State': 'New York',
#   'Lat': 40.7056258,
#   'long': -73.97968,
#   'Support': 3922,
#   'Oppose': 280,
#   'Overall': 'Oppose'},
#  {'State': 'North Carolina',
#   'Lat': 35.2145629,
#   'long': -79.8912675,
#   'Support': 1754,
#   'Oppose': 200,
#   'Overall': 'Oppose'},
#  {'State': 'North Dakota',
#   'Lat': 47.467881899999995,
#   'long': -100.3022655,
#   'Support': 109,
#   'Oppose': 14,
#   'Overall': 'Support'},
#  {'State': 'Ohio',
#   'Lat': 40.1903624,
#   'long': -82.6692525,
#   'Support': 2370,
#   'Oppose': 270,
#   'Overall': 'Oppose'},
#  {'State': 'Oklahoma',
#   'Lat': 35.309765399999996,
#   'long': -98.71655849999999,
#   'Support': 528,
#   'Oppose': 78,
#   'Overall': 'Oppose'},
#  {'State': 'Oregon',
#   'Lat': 44.1419049,
#   'long': -120.5380993,
#   'Support': 856,
#   'Oppose': 125,
#   'Overall': 'Oppose'},
#  {'State': 'Pennsylvania',
#   'Lat': 40.99459279999999,
#   'long': -77.6046984,
#   'Support': 3195,
#   'Oppose': 244,
#   'Overall': 'Oppose'},
#  {'State': 'Rhode Island',
#   'Lat': 41.5827282,
#   'long': -71.5064508,
#   'Support': 196,
#   'Oppose': 11,
#   'Overall': 'Support'},
#  {'State': 'South Carolina',
#   'Lat': 33.62505,
#   'long': -80.9470381,
#   'Support': 761,
#   'Oppose': 75,
#   'Overall': 'Oppose'},
#  {'State': 'South Dakota',
#   'Lat': 44.2126995,
#   'long': -100.24716409999999,
#   'Support': 137,
#   'Oppose': 25,
#   'Overall': 'Support'},
#  {'State': 'Tennessee',
#   'Lat': 35.830521000000005,
#   'long': -85.97859890000001,
#   'Support': 1059,
#   'Oppose': 126,
#   'Overall': 'Oppose'},
#  {'State': 'Texas',
#   'Lat': 31.1693363,
#   'long': -100.0768425,
#   'Support': 3839,
#   'Oppose': 483,
#   'Overall': 'Oppose'},
#  {'State': 'Utah',
#   'Lat': 39.4997605,
#   'long': -111.547028,
#   'Support': 432,
#   'Oppose': 75,
#   'Overall': 'Oppose'},
#  {'State': 'Vermont',
#   'Lat': 43.8717545,
#   'long': -72.4477828,
#   'Support': 110,
#   'Oppose': 17,
#   'Overall': 'Support'},
#  {'State': 'Virginia',
#   'Lat': 38.0033855,
#   'long': -79.4587861,
#   'Support': 1758,
#   'Oppose': 193,
#   'Overall': 'Oppose'},
#  {'State': 'Washington',
#   'Lat': 38.899348700000004,
#   'long': -77.0145665,
#   'Support': 1237,
#   'Oppose': 169,
#   'Overall': 'Oppose'},
#  {'State': 'West Virginia',
#   'Lat': 38.920170500000005,
#   'long': -80.1816905,
#   'Support': 364,
#   'Oppose': 55,
#   'Overall': 'Oppose'},
#  {'State': 'Wisconsin',
#   'Lat': 44.7862968,
#   'long': -89.82670490000001,
#   'Support': 1181,
#   'Oppose': 140,
#   'Overall': 'Oppose'},
#  {'State': 'Wyoming',
#   'Lat': 43.000325,
#   'long': -107.5545669,
#   'Support': 82,
#   'Oppose': 16,
#   'Overall': 'Support'}]

# %%
#############################################
# Filter by state how many respondents were supportive of Gun Background Checks
#############################################

StatesFor = session.query(CCES.StateName,CCES.Latitude, CCES.Longitude, func.count(CCES.GunBackgroundChecks_16)).filter(CCES.GunBackgroundChecks_16 == 'Support').group_by(CCES.StateName).all()
StatesNot = session.query(CCES.StateName, func.count(CCES.GunBackgroundChecks_16)).filter(CCES.GunBackgroundChecks_16 == 'Oppose').group_by(CCES.StateName).all()
print(StatesFor[0:5])
print(StatesNot[0:5])
# Out:
# [('Alabama', 32.601011199999995, -86.6807365, 676), ('Alaska', 61.3025006, -158.7750198, 85), ('Arizona', 34.1682185, -111.930907, 1265), ('Arkansas', 34.7519275, -92.13137840000002, 465), ('California', 37.2718745, -119.2704153, 5367)]
# [('Alabama', 88), ('Alaska', 24), ('Arizona', 200), ('Arkansas', 60), ('California', 493)]

# %%
#############################################
# Groupby Function testing before building function
#############################################
StatesForAbortion = session.query(CCES.StateName, func.count(CCES.AlwaysAllowChoice_16)).filter(CCES.AlwaysAllowChoice_16 == 'Support').group_by(CCES.StateName).all()
StatesNotAbortion = session.query(CCES.StateName, func.count(CCES.AlwaysAllowChoice_16)).filter(CCES.AlwaysAllowChoice_16 == 'Oppose').group_by(CCES.StateName).all()

ThirdTry = []

for i, j in zip(StatesForAbortion, StatesNotAbortion):

    tempfile = {}
    tempfile['State'] = i[0]
    tempfile['Support'] = i[1]
    tempfile['Oppose'] = j[1]
    if i[1] > j[1]:
        tempoverall = 'Support'
    else:
        tempoverall = 'Oppose'
    tempfile['Overall'] = tempoverall
        
    ThirdTry.append(tempfile)
ThirdTry
# Out:
# [{'State': {'support': 'Alabama'},
#   'Support': 397,
#   'Oppose': 367,
#   'Overall': 'Support'},
#  {'State': {'support': 'Alaska'},
#   'Support': 58,
#   'Oppose': 51,
#   'Overall': 'Support'},
#  {'State': {'support': 'Arizona'},
#   'Support': 867,
#   'Oppose': 598,
#   'Overall': 'Support'},
#  {'State': {'support': 'Arkansas'},
#   'Support': 231,
#   'Oppose': 294,
#   'Overall': 'Oppose'},
#  {'State': {'support': 'California'},
#   'Support': 4078,
#   'Oppose': 1782,
#   'Overall': 'Support'},
#  {'State': {'support': 'Colorado'},
#   'Support': 619,
#   'Oppose': 365,
#   'Overall': 'Support'},
#  {'State': {'support': 'Connecticut'},
#   'Support': 493,
#   'Oppose': 217,
#   'Overall': 'Support'},
#  {'State': {'support': 'Delaware'},
#   'Support': 187,
#   'Oppose': 74,
#   'Overall': 'Support'},
#  {'State': {'support': 'District of Columbia'},
#   'Support': 152,
#   'Oppose': 34,
#   'Overall': 'Support'},
#  {'State': {'support': 'Florida'},
#   'Support': 3111,
#   'Oppose': 1744,
#   'Overall': 'Support'},
#  {'State': {'support': 'Georgia'},
#   'Support': 1193,
#   'Oppose': 807,
#   'Overall': 'Support'},
#  {'State': {'support': 'Hawaii'},
#   'Support': 142,
#   'Oppose': 50,
#   'Overall': 'Support'},
#  {'State': {'support': 'Idaho'},
#   'Support': 163,
#   'Oppose': 154,
#   'Overall': 'Support'},
#  {'State': {'support': 'Illinois'},
#   'Support': 1777,
#   'Oppose': 792,
#   'Overall': 'Support'},
#  {'State': {'support': 'Indiana'},
#   'Support': 734,
#   'Oppose': 634,
#   'Overall': 'Support'},
#  {'State': {'support': 'Iowa'},
#   'Support': 370,
#   'Oppose': 299,
#   'Overall': 'Support'},
#  {'State': {'support': 'Kansas'},
#   'Support': 285,
#   'Oppose': 245,
#   'Overall': 'Support'},
#  {'State': {'support': 'Kentucky'},
#   'Support': 430,
#   'Oppose': 479,
#   'Overall': 'Oppose'},
#  {'State': {'support': 'Louisiana'},
#   'Support': 328,
#   'Oppose': 348,
#   'Overall': 'Oppose'},
#  {'State': {'support': 'Maine'},
#   'Support': 196,
#   'Oppose': 128,
#   'Overall': 'Support'},
#  {'State': {'support': 'Maryland'},
#   'Support': 833,
#   'Oppose': 334,
#   'Overall': 'Support'},
#  {'State': {'support': 'Massachusetts'},
#   'Support': 1051,
#   'Oppose': 351,
#   'Overall': 'Support'},
#  {'State': {'support': 'Michigan'},
#   'Support': 1235,
#   'Oppose': 837,
#   'Overall': 'Support'},
#  {'State': {'support': 'Minnesota'},
#   'Support': 651,
#   'Oppose': 403,
#   'Overall': 'Support'},
#  {'State': {'support': 'Mississippi'},
#   'Support': 205,
#   'Oppose': 194,
#   'Overall': 'Support'},
#  {'State': {'support': 'Missouri'},
#   'Support': 669,
#   'Oppose': 601,
#   'Overall': 'Support'},
#  {'State': {'support': 'Montana'},
#   'Support': 93,
#   'Oppose': 94,
#   'Overall': 'Oppose'},
#  {'State': {'support': 'Nebraska'},
#   'Support': 201,
#   'Oppose': 161,
#   'Overall': 'Support'},
#  {'State': {'support': 'Nevada'},
#   'Support': 484,
#   'Oppose': 202,
#   'Overall': 'Support'},
#  {'State': {'support': 'New Hampshire'},
#   'Support': 251,
#   'Oppose': 114,
#   'Overall': 'Support'},
#  {'State': {'support': 'New Jersey'},
#   'Support': 1223,
#   'Oppose': 561,
#   'Overall': 'Support'},
#  {'State': {'support': 'New Mexico'},
#   'Support': 239,
#   'Oppose': 135,
#   'Overall': 'Support'},
#  {'State': {'support': 'New York'},
#   'Support': 3043,
#   'Oppose': 1159,
#   'Overall': 'Support'},
#  {'State': {'support': 'North Carolina'},
#   'Support': 1159,
#   'Oppose': 795,
#   'Overall': 'Support'},
#  {'State': {'support': 'North Dakota'},
#   'Support': 70,
#   'Oppose': 53,
#   'Overall': 'Support'},
#  {'State': {'support': 'Ohio'},
#   'Support': 1512,
#   'Oppose': 1128,
#   'Overall': 'Support'},
#  {'State': {'support': 'Oklahoma'},
#   'Support': 297,
#   'Oppose': 309,
#   'Overall': 'Oppose'},
#  {'State': {'support': 'Oregon'},
#   'Support': 634,
#   'Oppose': 347,
#   'Overall': 'Support'},
#  {'State': {'support': 'Pennsylvania'},
#   'Support': 1978,
#   'Oppose': 1461,
#   'Overall': 'Support'},
#  {'State': {'support': 'Rhode Island'},
#   'Support': 150,
#   'Oppose': 57,
#   'Overall': 'Support'},
#  {'State': {'support': 'South Carolina'},
#   'Support': 418,
#   'Oppose': 418,
#   'Overall': 'Oppose'},
#  {'State': {'support': 'South Dakota'},
#   'Support': 88,
#   'Oppose': 74,
#   'Overall': 'Support'},
#  {'State': {'support': 'Tennessee'},
#   'Support': 591,
#   'Oppose': 594,
#   'Overall': 'Oppose'},
#  {'State': {'support': 'Texas'},
#   'Support': 2514,
#   'Oppose': 1808,
#   'Overall': 'Support'},
#  {'State': {'support': 'Utah'},
#   'Support': 216,
#   'Oppose': 291,
#   'Overall': 'Oppose'},
#  {'State': {'support': 'Vermont'},
#   'Support': 92,
#   'Oppose': 35,
#   'Overall': 'Support'},
#  {'State': {'support': 'Virginia'},
#   'Support': 1188,
#   'Oppose': 763,
#   'Overall': 'Support'},
#  {'State': {'support': 'Washington'},
#   'Support': 963,
#   'Oppose': 443,
#   'Overall': 'Support'},
#  {'State': {'support': 'West Virginia'},
#   'Support': 183,
#   'Oppose': 236,
#   'Overall': 'Oppose'},
#  {'State': {'support': 'Wisconsin'},
#   'Support': 771,
#   'Oppose': 550,
#   'Overall': 'Support'},
#  {'State': {'support': 'Wyoming'},
#   'Support': 56,
#   'Oppose': 42,
#   'Overall': 'Support'}]

# %%
#############################################
# Testing Groupby by specific state
# Filter by state how many respondents were supportive of Gun Background Checks
#############################################
AlabamaTotalExample = session.query(CCES.StateName, CCES.GayMarriage).filter(CCES.StateName == 'California').count()
AlabamaForExample = session.query(CCES.StateName, CCES.GayMarriage).filter(CCES.StateName == 'California').filter(CCES.GayMarriage == 'Support').count()
AlabamaAgainstExample = session.query(CCES.StateName, CCES.GayMarriage).filter(CCES.StateName == 'California').filter(CCES.GayMarriage == 'Oppose').count()
print(AlabamaTotalExample)
print(AlabamaForExample)
print(AlabamaAgainstExample)
